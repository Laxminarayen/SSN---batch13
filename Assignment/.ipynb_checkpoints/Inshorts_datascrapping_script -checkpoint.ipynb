# %% [markdown]
# ## Understand the scrapping scrpit below and start scrapping data from three areas of your interest and perform sentiment on the 'news headline'. Perform EDA and support your reasearch claims with proof.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
# %matplotlib inline

# %%
seed_urls = ['https://inshorts.com/en/read/technology',
             'https://inshorts.com/en/read/sports',
             'https://inshorts.com/en/read/world']

def build_dataset(seed_urls):
    news_data = []
    for url in seed_urls:
        news_category = url.split('/')[-1]
        data = requests.get(url)
        soup = BeautifulSoup(data.content, 'html.parser')
        
        news_articles = [{'news_headline': headline.find('span', 
                                                         attrs={"itemprop": "headline"}).string,
                          'news_article': article.find('div', 
                                                       attrs={"itemprop": "articleBody"}).string,
                          'news_category': news_category}
                         
                            for headline, article in 
                             zip(soup.find_all('div', 
                                               class_=["news-card-title news-right-box"]),
                                 soup.find_all('div', 
                                               class_=["news-card-content news-right-box"]))
                        ]
        news_data.extend(news_articles)
        
    df =  pd.DataFrame(news_data)
    df = df[['news_headline', 'news_article', 'news_category']]
    return df

# %%
news_df = build_dataset(seed_urls)
news_df.head(10)
# Out:
#                                        news_headline  \
# 0  Japan aquarium asks public to video-call eels ...
# 1  We saw 2 years of digital transformation in 2 ...
# 2  Chan Zuckerberg Initiative gives $13.6 mn to f...
# 3  8-10 of the 115 COVID-19 vaccine candidates lo...
# 4  Global smartphone market suffers the largest e...
# 5  Amazon predicts up to $1.5 billion loss in Q2 ...
# 6  Jio Platforms gets interest from global invest...
# 7  You're a disgrace: Ariana Grande's mom to Elon...
# 8  Lockdowns are fascist, give people back their ...
# 9  Pak operatives use fake Aarogya Setu app to ta...
#
#                                         news_article news_category
# 0  A Japan-based aquarium, which closed to the pu...    technology
# 1  Microsoft has seen two years' worth of digital...    technology
# 2  Facebook CEO Mark Zuckerberg and wife Priscill...    technology
# 3  Billionaire philanthropist Bill Gates has said...    technology
# 4  Global smartphone shipments witnessed their wo...    technology
# 5  Amazon said it could post its first quarterly ...    technology
# 6  After selling a 10% stake in its digital arm J...    technology
# 7  Ariana Grande's mother Joan Grande said Elon M...    technology
# 8  Tesla's billionaire CEO Elon Musk on Wednesday...    technology
# 9  The Indian Army has warned its personnel again...    technology
